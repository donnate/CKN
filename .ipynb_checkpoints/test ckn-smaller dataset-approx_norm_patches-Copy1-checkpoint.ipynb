# %%
# %matplotlib inline
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from CKN import *
from Nystrom import *
from image_processing_utils import *
import scipy.optimize

# %%
batch_size=64
test_batch_size=1000

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=test_batch_size, shuffle=True)

# %%
inds=range(60000)
import random
random.seed(2017)
random.shuffle(inds)

test=train_loader.dataset.train_data[inds[:3000],:,:]

# %%
X_labels=train_loader.dataset.train_labels[torch.LongTensor(inds[:3000])]

# %%
X_labels
# Out:
#  0
#  9
#  6
# ⋮
#  1
#  1
#  5
# [torch.LongTensor of size 3000]

# %%
import seaborn as sb
import math
import numpy as np

# %%
data=test
data=1.0/255*data.type(torch.FloatTensor)
#data2=data-torch.mean(data.view(-1,data.size()[1]*data.size()[2]),0).view(28,28)
#S=torch.std(data2.view(-1,data.size()[1]*data.size()[2]),0)
#S[S==0]=1
#data2=1.0/255*data2.view(-1,data.size()[1]*data.size()[2])
#data2=data2.view(-1,28,28)

# %%
net=CKN()
net=CKN(n_components=[50,200],n_layers=2,iter_max=50,n_patches=[5,2],subsampling_factors=[2,2],batch_size=[60,60,60])#Cell.fit_LBFGS(X)
net.train_network(data)
# Out:
# torch.Size([3000, 28, 28])
# patches extracted with size  torch.Size([784, 3000, 25])
# torch.Size([784, 3000, 15])
# [[0, 20, 430], [0, 14, 238], [0, 116, 170], [0, 248, 280], [0, 320, 418], [0, 718, 595], [0, 99, 397], [0, 39, 757], [0, 477, 343], [0, 104, 12]]
# ('sel', torch.Size([90000, 2, 15]))
# ('The data has size', torch.Size([784, 3000, 15]))
# ('all okay', True)
# ('The variance is: ', 11.915099143981934)
# ('size input: ', torch.Size([90000, 2, 15]))
# (0,
# 1.00000e-02 *
#   1.2102
# [torch.FloatTensor of size 1]
# , 8.205935001373291)
# (1,
# 1.00000e-03 *
#   5.2001
# [torch.FloatTensor of size 1]
# , 8.666002035140991)
# (2,
# 1.00000e-03 *
#   3.5876
# [torch.FloatTensor of size 1]
# , 7.861236095428467)
# (3,
# 1.00000e-03 *
#   2.6952
# [torch.FloatTensor of size 1]
# , 7.75973105430603)
# (4,
# 1.00000e-03 *
#   2.1798
# [torch.FloatTensor of size 1]
# , 7.815492153167725)
# (5,
# 1.00000e-03 *
#   1.8450
# [torch.FloatTensor of size 1]
# , 7.997330904006958)
# (6,
# 1.00000e-03 *
#   1.6000
# [torch.FloatTensor of size 1]
# , 8.243337869644165)
# (7,
# 1.00000e-03 *
#   1.4110
# [torch.FloatTensor of size 1]
# , 8.455101013183594)
# (8,
# 1.00000e-03 *
#   1.2588
# [torch.FloatTensor of size 1]
# , 8.307252168655396)
# (9,
# 1.00000e-03 *
#   1.1335
# [torch.FloatTensor of size 1]
# , 8.327527046203613)
# (10,
# 1.00000e-03 *
#   1.0292
# [torch.FloatTensor of size 1]
# , 8.192905902862549)
# (11,
# 1.00000e-04 *
#   9.4175
# [torch.FloatTensor of size 1]
# , 8.291243076324463)
# (12,
# 1.00000e-04 *
#   8.6807
# [torch.FloatTensor of size 1]
# , 8.493093967437744)
# (13,
# 1.00000e-04 *
#   8.0554
# [torch.FloatTensor of size 1]
# , 8.536874771118164)
# (14,
# 1.00000e-04 *
#   7.5214
# [torch.FloatTensor of size 1]
# , 8.50211787223816)
# (15,
# 1.00000e-04 *
#   7.0635
# [torch.FloatTensor of size 1]
# , 8.31020712852478)
# (16,
# 1.00000e-04 *
#   6.6686
# [torch.FloatTensor of size 1]
# , 7.985395193099976)
# (17,
# 1.00000e-04 *
#   6.3257
# [torch.FloatTensor of size 1]
# , 7.781649112701416)
# (18,
# 1.00000e-04 *
#   6.0260
# [torch.FloatTensor of size 1]
# , 7.858911037445068)
# (19,
# 1.00000e-04 *
#   5.7624
# [torch.FloatTensor of size 1]
# , 7.648616075515747)
# (20,
# 1.00000e-04 *
#   5.5296
# [torch.FloatTensor of size 1]
# , 9.009591817855835)
# (21,
# 1.00000e-04 *
#   5.3228
# [torch.FloatTensor of size 1]
# , 7.517251968383789)
# (22,
# 1.00000e-04 *
#   5.1379
# [torch.FloatTensor of size 1]
# , 8.028409957885742)
# (23,
# 1.00000e-04 *
#   4.9722
# [torch.FloatTensor of size 1]
# , 7.567438125610352)
# (24,
# 1.00000e-04 *
#   4.8237
# [torch.FloatTensor of size 1]
# , 9.139299869537354)
# (25,
# 1.00000e-04 *
#   4.6897
# [torch.FloatTensor of size 1]
# , 8.638957023620605)
# (26,
# 1.00000e-04 *
#   4.5687
# [torch.FloatTensor of size 1]
# , 7.580415964126587)
# (27,
# 1.00000e-04 *
#   4.4590
# [torch.FloatTensor of size 1]
# , 7.770854949951172)
# (28,
# 1.00000e-04 *
#   4.3590
# [torch.FloatTensor of size 1]
# , 7.786819934844971)
# (29,
# 1.00000e-04 *
#   4.2674
# [torch.FloatTensor of size 1]
# , 7.538950204849243)
# (30,
# 1.00000e-04 *
#   4.1832
# [torch.FloatTensor of size 1]
# , 7.876906871795654)
# (31,
# 1.00000e-04 *
#   4.1052
# [torch.FloatTensor of size 1]
# , 8.68172001838684)
# (32,
# 1.00000e-04 *
#   4.0328
# [torch.FloatTensor of size 1]
# , 8.362830877304077)
# (33,
# 1.00000e-04 *
#   3.9653
# [torch.FloatTensor of size 1]
# , 8.28027892112732)
# (34,
# 1.00000e-04 *
#   3.9021
# [torch.FloatTensor of size 1]
# , 7.826178073883057)
# (35,
# 1.00000e-04 *
#   3.8426
# [torch.FloatTensor of size 1]
# , 8.653478145599365)
# (36,
# 1.00000e-04 *
#   3.7865
# [torch.FloatTensor of size 1]
# , 8.653146028518677)
# (37,
# 1.00000e-04 *
#   3.7335
# [torch.FloatTensor of size 1]
# , 9.471943855285645)
# (38,
# 1.00000e-04 *
#   3.6832
# [torch.FloatTensor of size 1]
# , 8.342441082000732)
# (39,
# 1.00000e-04 *
#   3.6354
# [torch.FloatTensor of size 1]
# , 8.064556121826172)
# (40,
# 1.00000e-04 *
#   3.5897
# [torch.FloatTensor of size 1]
# , 8.01912784576416)
# (41,
# 1.00000e-04 *
#   3.5461
# [torch.FloatTensor of size 1]
# , 7.666485786437988)
# (42,
# 1.00000e-04 *
#   3.5043
# [torch.FloatTensor of size 1]
# , 7.246407985687256)
# (43,
# 1.00000e-04 *
#   3.4641
# [torch.FloatTensor of size 1]
# , 7.249199151992798)
# (44,
# 1.00000e-04 *
#   3.4253
# [torch.FloatTensor of size 1]
# , 7.292610168457031)
# (45,
# 1.00000e-04 *
#   3.3878
# [torch.FloatTensor of size 1]
# , 7.206914901733398)
# (46,
# 1.00000e-04 *
#   3.3516
# [torch.FloatTensor of size 1]
# , 7.239292144775391)
# (47,
# 1.00000e-04 *
#   3.3164
# [torch.FloatTensor of size 1]
# , 7.353480815887451)
# (48,
# 1.00000e-04 *
#   3.2823
# [torch.FloatTensor of size 1]
# , 8.08560299873352)
# (49,
# 1.00000e-04 *
#   3.2491
# [torch.FloatTensor of size 1]
# , 8.46687388420105)
# (32, 32)
# 0
# ('tot', 0.8301568031311035)
# ('w', 0.9460694193840027)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 1
# ('tot', 0.8374484777450562)
# ('w', 0.9443045258522034)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 2
# ('tot', 0.8421793580055237)
# ('w', 0.9690596461296082)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 3
# ('tot', 0.8329569697380066)
# ('w', 0.9528169631958008)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 4
# ('tot', 0.8422954678535461)
# ('w', 0.9778222441673279)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 5
# ('tot', 0.8373443484306335)
# ('w', 0.9678502082824707)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 6
# ('tot', 0.8379260301589966)
# ('w', 0.9692565202713013)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 7
# ('tot', 0.8312038779258728)
# ('w', 0.9679530262947083)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 8
# ('tot', 0.8541856408119202)
# ('w', 0.9677279591560364)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 9
# ('tot', 0.8461835384368896)
# ('w', 0.9695417284965515)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 10
# ('tot', 0.8577393889427185)
# ('w', 0.968925416469574)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 11
# ('tot', 0.8415886759757996)
# ('w', 0.9614506959915161)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 12
# ('tot', 0.8423362374305725)
# ('w', 0.9592759609222412)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 13
# ('tot', 0.8363597989082336)
# ('w', 0.9673385620117188)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 14
# ('tot', 0.8321906328201294)
# ('w', 0.9580345153808594)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 15
# ('tot', 0.8321526050567627)
# ('w', 0.960160493850708)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 16
# ('tot', 0.8417316675186157)
# ('w', 0.9548876881599426)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 17
# ('tot', 0.8415064811706543)
# ('w', 0.9759742021560669)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 18
# ('tot', 0.8636319041252136)
# ('w', 0.9457693099975586)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 19
# ('tot', 0.8318067789077759)
# ('w', 0.9583234190940857)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 20
# ('tot', 0.8298388719558716)
# ('w', 0.9735570549964905)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 21
# ('tot', 0.8388122916221619)
# ('w', 0.9617810845375061)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 22
# ('tot', 0.8418381214141846)
# ('w', 0.9546847343444824)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 23
# ('tot', 0.8402379155158997)
# ('w', 0.9657631516456604)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 24
# ('tot', 0.8398821949958801)
# ('w', 0.9654892683029175)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 25
# ('tot', 0.8440443277359009)
# ('w', 0.9558690190315247)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 26
# ('tot', 0.8417113423347473)
# ('w', 0.9591289162635803)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 27
# ('tot', 0.8390964269638062)
# ('w', 0.9681814312934875)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 28
# ('tot', 0.8390299677848816)
# ('w', 0.9447190165519714)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# 29
# ('tot', 0.8555951118469238)
# ('w', 0.9728423357009888)
# ('nb 1 of null is ', 0)
# torch.Size([78400, 50])
# torch.Size([784, 3000])
# ('Reg', 3.2190186977386475)
# ('zeta', torch.Size([78400, 50]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([784, 100, 50]))
# ('nb 3 of null is ', 0)
# ('nb final of null is ', 0)
# ('size out', torch.Size([196, 3000, 50]))
# torch.Size([196, 3000, 50])
# patches extracted with size  torch.Size([196, 3000, 200])
# torch.Size([196, 3000, 15])
# [[0, 109, 82], [0, 155, 181], [0, 21, 1], [0, 171, 28], [0, 158, 93], [0, 65, 57], [0, 65, 182], [0, 140, 80], [0, 89, 124], [0, 121, 116]]
# ('sel', torch.Size([60000, 2, 15]))
# ('The data has size', torch.Size([196, 3000, 15]))
# ('all okay', True)
# ('The variance is: ', 35.324663162231445)
# ('size input: ', torch.Size([60000, 2, 15]))
# (0,
# 1.00000e-03 *
#   9.5565
# [torch.FloatTensor of size 1]
# , 27.092535972595215)
# (1,
# 1.00000e-03 *
#   2.0394
# [torch.FloatTensor of size 1]
# , 26.468207836151123)
# (2,
# 1.00000e-03 *
#   1.4285
# [torch.FloatTensor of size 1]
# , 26.79569697380066)
# (3,
# 1.00000e-03 *
#   1.1488
# [torch.FloatTensor of size 1]
# , 26.161952018737793)
# (4,
# 1.00000e-04 *
#   9.7047
# [torch.FloatTensor of size 1]
# , 25.860285997390747)
# (5,
# 1.00000e-04 *
#   8.3960
# [torch.FloatTensor of size 1]
# , 26.635281085968018)
# (6,
# 1.00000e-04 *
#   7.3895
# [torch.FloatTensor of size 1]
# , 26.312683820724487)
# (7,
# 1.00000e-04 *
#   6.6033
# [torch.FloatTensor of size 1]
# , 26.195247888565063)
# (8,
# 1.00000e-04 *
#   5.9773
# [torch.FloatTensor of size 1]
# , 26.354562997817993)
# (9,
# 1.00000e-04 *
#   5.4722
# [torch.FloatTensor of size 1]
# , 26.787694931030273)
# (10,
# 1.00000e-04 *
#   5.0576
# [torch.FloatTensor of size 1]
# , 27.235037088394165)
# (11,
# 1.00000e-04 *
#   4.7135
# [torch.FloatTensor of size 1]
# , 26.079133987426758)
# (12,
# 1.00000e-04 *
#   4.4237
# [torch.FloatTensor of size 1]
# , 26.11922001838684)
# (13,
# 1.00000e-04 *
#   4.1758
# [torch.FloatTensor of size 1]
# , 26.545030117034912)
# (14,
# 1.00000e-04 *
#   3.9605
# [torch.FloatTensor of size 1]
# , 26.017584800720215)
# (15,
# 1.00000e-04 *
#   3.7708
# [torch.FloatTensor of size 1]
# , 26.086466073989868)
# (16,
# 1.00000e-04 *
#   3.6024
# [torch.FloatTensor of size 1]
# , 26.20127511024475)
# (17,
# 1.00000e-04 *
#   3.4512
# [torch.FloatTensor of size 1]
# , 26.692743062973022)
# (18,
# 1.00000e-04 *
#   3.3149
# [torch.FloatTensor of size 1]
# , 25.909446954727173)
# (19,
# 1.00000e-04 *
#   3.1912
# [torch.FloatTensor of size 1]
# , 26.511409044265747)
# (20,
# 1.00000e-04 *
#   3.0785
# [torch.FloatTensor of size 1]
# , 26.505742073059082)
# (21,
# 1.00000e-04 *
#   2.9757
# [torch.FloatTensor of size 1]
# , 26.32927703857422)
# (22,
# 1.00000e-04 *
#   2.8815
# [torch.FloatTensor of size 1]
# , 27.820363998413086)
# (23,
# 1.00000e-04 *
#   2.7947
# [torch.FloatTensor of size 1]
# , 26.9571750164032)
# (24,
# 1.00000e-04 *
#   2.7147
# [torch.FloatTensor of size 1]
# , 26.15373682975769)
# (25,
# 1.00000e-04 *
#   2.6409
# [torch.FloatTensor of size 1]
# , 30.073926210403442)
# (26,
# 1.00000e-04 *
#   2.5724
# [torch.FloatTensor of size 1]
# , 29.989871978759766)
# (27,
# 1.00000e-04 *
#   2.5089
# [torch.FloatTensor of size 1]
# , 24.737246990203857)
# (28,
# 1.00000e-04 *
#   2.4497
# [torch.FloatTensor of size 1]
# , 26.03037691116333)
# (29,
# 1.00000e-04 *
#   2.3946
# [torch.FloatTensor of size 1]
# , 25.80129313468933)
# (30,
# 1.00000e-04 *
#   2.3431
# [torch.FloatTensor of size 1]
# , 26.649662971496582)
# (31,
# 1.00000e-04 *
#   2.2947
# [torch.FloatTensor of size 1]
# , 26.105929851531982)
# (32,
# 1.00000e-04 *
#   2.2493
# [torch.FloatTensor of size 1]
# , 26.326567888259888)
# (33,
# 1.00000e-04 *
#   2.2067
# [torch.FloatTensor of size 1]
# , 26.554061889648438)
# (34,
# 1.00000e-04 *
#   2.1664
# [torch.FloatTensor of size 1]
# , 26.413106203079224)
# (35,
# 1.00000e-04 *
#   2.1283
# [torch.FloatTensor of size 1]
# , 27.257494926452637)
# (36,
# 1.00000e-04 *
#   2.0922
# [torch.FloatTensor of size 1]
# , 27.108360052108765)
# (37,
# 1.00000e-04 *
#   2.0580
# [torch.FloatTensor of size 1]
# , 26.203995943069458)
# (38,
# 1.00000e-04 *
#   2.0254
# [torch.FloatTensor of size 1]
# , 26.213171005249023)
# (39,
# 1.00000e-04 *
#   1.9944
# [torch.FloatTensor of size 1]
# , 26.441020011901855)
# (40,
# 1.00000e-04 *
#   1.9648
# [torch.FloatTensor of size 1]
# , 26.000699996948242)
# (41,
# 1.00000e-04 *
#   1.9365
# [torch.FloatTensor of size 1]
# , 26.369122982025146)
# (42,
# 1.00000e-04 *
#   1.9093
# [torch.FloatTensor of size 1]
# , 25.659146070480347)
# (43,
# 1.00000e-04 *
#   1.8833
# [torch.FloatTensor of size 1]
# , 26.096615076065063)
# (44,
# 1.00000e-04 *
#   1.8583
# [torch.FloatTensor of size 1]
# , 26.13478684425354)
# (45,
# 1.00000e-04 *
#   1.8342
# [torch.FloatTensor of size 1]
# , 25.876792907714844)
# (46,
# 1.00000e-04 *
#   1.8109
# [torch.FloatTensor of size 1]
# , 26.1238009929657)
# (47,
# 1.00000e-04 *
#   1.7885
# [torch.FloatTensor of size 1]
# , 26.14660406112671)
# (48,
# 1.00000e-04 *
#   1.7668
# [torch.FloatTensor of size 1]
# , 25.971326112747192)
# (49,
# 1.00000e-04 *
#   1.7458
# [torch.FloatTensor of size 1]
# , 26.16411280632019)
# (16, 16)
# 0
# ('tot', 0.9697243571281433)
# ('w', 1.0371019840240479)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 1
# ('tot', 0.9741939902305603)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 2
# ('tot', 0.9703086614608765)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 3
# ('tot', 0.9763923287391663)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 4
# ('tot', 0.9745057821273804)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 5
# ('tot', 0.973508358001709)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 6
# ('tot', 0.972123920917511)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 7
# ('tot', 0.9722095131874084)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 8
# ('tot', 0.9702889919281006)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 9
# ('tot', 0.9740637540817261)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 10
# ('tot', 0.9724931120872498)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 11
# ('tot', 0.9730543494224548)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 12
# ('tot', 0.9727307558059692)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 13
# ('tot', 0.9715445041656494)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 14
# ('tot', 0.974804699420929)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 15
# ('tot', 0.9753557443618774)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 16
# ('tot', 0.9770700335502625)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 17
# ('tot', 0.9715912342071533)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 18
# ('tot', 0.9701701998710632)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 19
# ('tot', 0.9702374935150146)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 20
# ('tot', 0.9730391502380371)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 21
# ('tot', 0.9728444814682007)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 22
# ('tot', 0.9702961444854736)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 23
# ('tot', 0.9810481071472168)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 24
# ('tot', 0.9711537957191467)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 25
# ('tot', 0.9703109264373779)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 26
# ('tot', 0.9702342748641968)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 27
# ('tot', 0.9784032702445984)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 28
# ('tot', 0.971093475818634)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# 29
# ('tot', 0.9703110456466675)
# ('w', 1.0369187593460083)
# ('nb 1 of null is ', 0)
# torch.Size([19600, 200])
# torch.Size([196, 3000])
# ('Reg', 85.5609359741211)
# ('zeta', torch.Size([19600, 200]))
# ('nb 2 of null is ', 0)
# ('test', torch.Size([196, 100, 200]))
# ('nb 3 of null is ', 0)
# ('nb final of null is ', 0)
# ('size out', torch.Size([49, 3000, 200]))
# ( 0  ,.,.) =
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#               ...                ⋱                ...
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#
# ( 1  ,.,.) =
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0001    0.0098    0.0002  ...     0.0001    0.0014    0.0170
#               ...                ⋱                ...
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#
# ( 2  ,.,.) =
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0027    0.0482    0.0050  ...     0.0029    0.0464    0.0730
#               ...                ⋱                ...
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#  ...
#
# ( 46 ,.,.) =
#    26.1126   10.4881   14.1326  ...     8.0603    3.1217    2.1409
#    49.9602   14.7075    6.7146  ...     6.3369    1.9739    2.4558
#    28.5773    9.4246    9.8600  ...     7.2774    0.8627    1.6193
#               ...                ⋱                ...
#    25.7709    7.1151    3.8518  ...     4.4273    0.9050    1.4327
#    19.3362    7.2360    2.0328  ...     1.9467    0.8016    1.3852
#    39.4385   15.4588   19.0757  ...    12.0312    3.4627    2.5695
#
# ( 47 ,.,.) =
#    19.3171    6.9739    3.0975  ...     2.1935    0.7136    1.2516
#     2.7333    6.7738    0.6946  ...     0.3169    0.4391    1.0744
#    13.0664    7.7314    2.3973  ...     1.4315    0.5404    1.2557
#               ...                ⋱                ...
#     0.2441    3.3075    0.2004  ...     0.0752    0.1991    0.5009
#     0.1052    1.9184    0.1307  ...     0.0503    0.1068    0.2833
#    27.3361   11.0437    3.1200  ...     2.3212    0.9833    1.8128
#
# ( 48 ,.,.) =
#     0.6001    2.6304    0.2746  ...     0.1210    0.1551    0.3998
#     0.0113    0.4126    0.0236  ...     0.0101    0.0176    0.0540
#     0.6720    3.1848    0.3242  ...     0.1427    0.1777    0.4530
#               ...                ⋱                ...
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.0000    0.0000    0.0000  ...     0.0000    0.0000    0.0000
#     0.4030    3.5806    0.2518  ...     0.0999    0.2052    0.5446
# [torch.FloatTensor of size 49x3000x200]

# %%
print(net.Kernel[0].eta.data)
self=net
sb.heatmap(net.Kernel[0].W.data.numpy())
plt.figure()
# Out:
#  1.0013
#  2.0988
#  0.8714
#  0.6142
#  0.8231
#  0.9896
#  1.1069
#  1.1961
#  1.1292
#  1.0060
#  1.1178
#  1.0244
#  1.1523
#  1.1418
#  1.2572
#  0.8584
#  1.1156
#  1.0350
#  0.8028
#  0.8967
#  1.2530
#  1.0320
#  1.0109
#  0.9844
#  1.6067
#  0.9300
#  0.9641
#  1.7469
#  0.8393
#  1.0853
#  0.8199
#  1.1261
#  1.0399
#  0.9908
#  1.1690
#  0.9149
#  1.0929
#  0.8317
#  1.4079
#  1.1414
#  0.8628
#  1.5474
#  1.0603
#  1.0034
#  1.2397
#  1.3678
#  1.4932
#  1.1383
#  0.9924
#  0.9730
# [torch.FloatTensor of size 50]

# %%
net.Kernel[0].convergence_check()
# Out:
# torch.Size([90000, 2, 15])
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
net.Kernel[1].convergence_check()
# Out:
# torch.Size([60000, 2, 15])
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
plt.plot([ u.numpy() for u in net.Kernel[0].training_loss])
plt.plot([ u.numpy() for u in net.Kernel[1].training_loss],c='yellow')

# %%
net.Kernel[1].eta
# Out:
# Variable containing:
#  0.0900
#  1.8786
#  0.2044
#  0.0693
#  0.1582
#  0.1878
#  0.1617
#  0.1847
#  0.1296
#  0.3614
#  0.2360
#  0.0759
#  0.0379
#  0.0882
#  0.1010
#  0.1046
#  0.4657
#  0.4187
#  0.1524
#  0.0987
#  0.2276
#  0.1193
#  0.1401
#  0.4001
#  0.3472
#  0.0068
#  0.3809
#  0.2372
#  0.0206
#  0.0619
#  0.0028
#  0.2195
#  0.4426
#  0.1086
#  0.1194
#  0.1723
#  0.0906
#  0.3047
#  0.4812
#  0.1432
#  0.0310
#  0.2315
#  0.0805
#  0.1376
#  0.2879
#  0.1117
#  0.2763
#  0.4362
#  0.2427
#  0.0908
#  0.2061
#  0.1528
#  0.1745
#  0.1389
#  0.4442
#  0.1163
#  0.1324
#  0.0665
#  0.1231
#  0.6389
#  0.2612
#  0.1733
#  0.5225
#  0.1643
#  0.3024
#  0.2318
#  0.0096
#  0.3312
#  0.2032
#  0.0800
#  0.2709
#  0.0725
#  0.1742
#  0.1814
#  0.2594
#  0.1578
#  0.0446
#  0.3306
#  0.1642
#  0.3903
#  0.1086
#  0.0288
#  0.2252
#  0.1426
#  0.4570
#  0.2133
#  0.0271
#  0.1879
#  0.1597
#  0.2253
#  0.1873
#  0.1763
#  0.0208
#  0.2085
#  0.1931
#  0.2255
#  0.1970
#  0.0342
#  0.2088
#  0.1814
#  0.4425
#  0.1738
#  0.0215
#  0.1382
#  0.1719
#  0.7512
#  0.2067
#  0.0499
#  0.1439
#  0.2186
#  0.3926
#  0.2074
#  0.1847
#  0.0244
#  0.3846
#  0.2059
#  0.1266
#  0.0959
#  0.0933
#  0.2469
#  0.1103
#  0.1297
#  0.0696
#  0.1042
#  0.1399
#  0.1675
#  0.1058
#  0.0522
#  0.1877
#  0.1731
#  0.0986
#  0.1149
#  0.1709
#  0.3699
#  0.1884
#  0.0628
#  0.3555
#  0.1886
#  0.2091
#  0.1540
#  0.2291
#  0.5118
#  0.0988
#  0.3866
#  0.2756
#  0.4670
#  0.1180
#  0.4020
#  0.0528
#  0.1148
#  0.1890
#  0.1209
#  0.3639
#  0.0177
#  0.1604
#  0.0618
#  0.1286
#  0.6261
#  0.2695
#  0.1030
#  0.0568
#  0.0560
#  0.1865
#  0.1293
#  0.3940
#  0.0850
#  0.1279
#  0.1917
#  0.1883
#  0.4685
#  0.1763
#  0.2127
#  0.0419
#  0.2456
#  0.1333
#  0.2365
#  0.1402
#  0.0880
#  0.0909
#  0.0769
#  0.0090
#  0.1961
#  0.1123
#  0.1472
#  0.1385
#  0.0573
#  0.1687
#  0.1659
#  0.2036
#  0.1296
#  0.0280
#  0.0912
#  0.0241
#  0.0113
#  0.3023
#  0.1734
#  0.4015
#  0.0564
#  0.0880
#  0.1993
# [torch.FloatTensor of size 200]

# %%
print(net.Kernel[0].output.size())
sb.heatmap(net.Kernel[0].output[100,:100,:].numpy())
print(X_labels[:10])
# Out:
# torch.Size([196, 3000, 50])
#
#  0
#  9
#  6
#  1
#  2
#  3
#  9
#  2
#  4
#  3
# [torch.LongTensor of size 10]

# %%
plt.plot([ u.numpy() for u in net.Kernel[1].training_loss])

# %%
sb.heatmap(test.W.data.numpy())

# %%
X_tot=net.Kernel[1].eta
X_tot
#X_tot_2=test.pca.transform(X_tot.view(-1,X_tot.size()[2]).numpy())

# %%
# Import datasets, classifiers and performance metrics
from sklearn import datasets, svm, pipeline
from sklearn.kernel_approximation import (RBFSampler,
                                          Nystroem)
from sklearn.decomposition import PCA
X=net.Kernel[1].output

# %%
n_p,n_d,p_dim=X.size()
print(X.size())
X=X.permute(1,0,2)
print(X.size())
pca_mnist=PCA(n_components=15,whiten=True)
X2=pca_mnist.fit_transform(X.contiguous().view(n_d, n_p*p_dim).numpy())
X2.shape
# Out:
# torch.Size([49, 3000, 200])
# torch.Size([3000, 49, 200])
# (3000, 15)

# %%
XX=X.permute(1,0,2).contiguous().view(n_d,-1).numpy()
kernel_svm_score=[]
it=0
for s in np.arange(0.01,0.9,0.02):
    kernel_svm = svm.SVC(gamma=s)
    kernel_svm.fit(XX, X_labels.numpy())
    kernel_svm_score.append( kernel_svm.score(XX, X_labels.numpy()))
    print(s,kernel_svm_score[it])
    it+=1
#kernel_svm.fit(X.permute(1,0,2).contiguous().view(n_d,-1).numpy(), X_labels.numpy())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-0aea688dcfe8> in <module>()
#       5     kernel_svm = svm.SVC(gamma=s)
#       6     kernel_svm.fit(XX, X_labels.numpy())
# ----> 7     kernel_svm_score[it] = kernel_svm.score(XX, X_labels.numpy())
#       8     print(s,kernel_svm_score[it])
#       9     it+=1
#
# IndexError: list assignment index out of range

# %%
#### Une fois que l'archtexture a ete entrainee on peut se servir de la couche finale pour faire de la prediction
kernel_svm_score = kernel_svm.score(X.permute(1,0,2).contiguous().view(n_d,-1).numpy(), X_labels.numpy())

# %%
np.arange(0.01,0.9,0.02)
# Out:
# array([ 0.01,  0.03,  0.05,  0.07,  0.09,  0.11,  0.13,  0.15,  0.17,
#         0.19,  0.21,  0.23,  0.25,  0.27,  0.29,  0.31,  0.33,  0.35,
#         0.37,  0.39,  0.41,  0.43,  0.45,  0.47,  0.49,  0.51,  0.53,
#         0.55,  0.57,  0.59,  0.61,  0.63,  0.65,  0.67,  0.69,  0.71,
#         0.73,  0.75,  0.77,  0.79,  0.81,  0.83,  0.85,  0.87,  0.89])

# %%
X_test=train_loader.dataset.train_data[torch.LongTensor(inds[3000:6000])]
X_test_labels=train_loader.dataset.train_labels[torch.LongTensor(inds[3000:6000])]

# %%
X_test.size()
