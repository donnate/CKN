# %%
# %matplotlib inline
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from CKN import *
from Nystrom import *
from image_processing_utils import *
import scipy.optimize

# %%
batch_size=64
test_batch_size=1000

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=test_batch_size, shuffle=True)

# %%
inds=range(60000)
import random
random.seed(2017)
random.shuffle(inds)

test=train_loader.dataset.train_data[inds[:3000],:,:]

# %%
X_labels=train_loader.dataset.train_labels[torch.LongTensor(inds[:3000])]

# %%
X_labels
# Out:
#  0
#  9
#  6
# ⋮
#  1
#  1
#  5
# [torch.LongTensor of size 3000]

# %%
import seaborn as sb
import math
import numpy as np

# %%
data=test
data=data.type(torch.FloatTensor)
data2=data-torch.mean(data.view(-1,data.size()[1]*data.size()[2]),0).view(28,28)
S=torch.std(data2.view(-1,data.size()[1]*data.size()[2]),0)
S[S==0]=1
data2=1.0/S*data2.view(-1,data.size()[1]*data.size()[2])
data2=data2.view(-1,28,28)

# %%
net=CKN()
net=CKN(n_components=[150,100,100],n_layers=3,iter_max=100,n_patches=[5,2,2],subsampling_factors=[2,2,2],batch_size=[60,60,60])#Cell.fit_LBFGS(X)
net.train_network(data2)
# Out:
# torch.Size([3000, 28, 28])
# ('patches extracted with size ', torch.Size([784, 3000, 25]))
# [[0, 621, 678], [0, 657, 443], [0, 398, 57], [0, 237, 682], [0, 397, 178], [0, 380, 251], [0, 370, 747], [0, 517, 173], [0, 384, 428], [0, 542, 500]]
# ('sel', torch.Size([30000, 2, 25]))
# ('The data has size', torch.Size([784, 3000, 25]))
# ('all okay', True)
# ('The variance is: ', 0.11568539589643478)
# ('inf values:', 0)
# ('na values:', 0)
# ('size input: ', torch.Size([30000, 2, 15]))
# (0,
# 1.00000e-02 *
#   5.5985
# [torch.FloatTensor of size 1]
# , 8.568251848220825)
# (1,
# 1.00000e-03 *
#   9.1404
# [torch.FloatTensor of size 1]
# , 8.533531188964844)
# (2,
# 1.00000e-03 *
#   8.4725
# [torch.FloatTensor of size 1]
# , 9.787598133087158)
# (3,
# 1.00000e-03 *
#   7.5691
# [torch.FloatTensor of size 1]
# , 9.888105869293213)
# (4,
# 1.00000e-03 *
#   6.6938
# [torch.FloatTensor of size 1]
# , 12.409933090209961)
# (5,
# 1.00000e-03 *
#   6.0414
# [torch.FloatTensor of size 1]
# , 10.058951139450073)
# (6,
# 1.00000e-03 *
#   5.5550
# [torch.FloatTensor of size 1]
# , 11.383762836456299)
# (7,
# 1.00000e-03 *
#   5.1639
# [torch.FloatTensor of size 1]
# , 9.428797960281372)
# (8,
# 1.00000e-03 *
#   4.8583
# [torch.FloatTensor of size 1]
# , 8.877308130264282)
# (9,
# 1.00000e-03 *
#   4.6211
# [torch.FloatTensor of size 1]
# , 8.777496814727783)
# (10,
# 1.00000e-03 *
#   4.4365
# [torch.FloatTensor of size 1]
# , 8.884429216384888)
# (11,
# 1.00000e-03 *
#   4.2912
# [torch.FloatTensor of size 1]
# , 10.534056901931763)
# (12,
# 1.00000e-03 *
#   4.1738
# [torch.FloatTensor of size 1]
# , 9.881258010864258)
# (13,
# 1.00000e-03 *
#   4.0749
# [torch.FloatTensor of size 1]
# , 9.2119460105896)
# (14,
# 1.00000e-03 *
#   3.9866
# [torch.FloatTensor of size 1]
# , 10.825891017913818)
# (15,
# 1.00000e-03 *
#   3.9017
# [torch.FloatTensor of size 1]
# , 10.051562070846558)
# (16,
# 1.00000e-03 *
#   3.8116
# [torch.FloatTensor of size 1]
# , 8.325950145721436)
# (17,
# 1.00000e-03 *
#   3.7059
# [torch.FloatTensor of size 1]
# , 8.403775930404663)
# (18,
# 1.00000e-03 *
#   3.5803
# [torch.FloatTensor of size 1]
# , 8.52098298072815)
# (19,
# 1.00000e-03 *
#   3.4560
# [torch.FloatTensor of size 1]
# , 8.377352952957153)
# (20,
# 1.00000e-03 *
#   3.3627
# [torch.FloatTensor of size 1]
# , 8.425544023513794)
# (21,
# 1.00000e-03 *
#   3.2878
# [torch.FloatTensor of size 1]
# , 8.730072975158691)
# (22,
# 1.00000e-03 *
#   3.1916
# [torch.FloatTensor of size 1]
# , 8.27596116065979)
# (23,
# 1.00000e-03 *
#   3.0840
# [torch.FloatTensor of size 1]
# , 8.313638925552368)
# (24,
# 1.00000e-03 *
#   3.0256
# [torch.FloatTensor of size 1]
# , 9.022504091262817)
# (25,
# 1.00000e-03 *
#   2.9958
# [torch.FloatTensor of size 1]
# , 8.313097953796387)
# (26,
# 1.00000e-03 *
#   2.9714
# [torch.FloatTensor of size 1]
# , 8.763795137405396)
# (27,
# 1.00000e-03 *
#   2.9471
# [torch.FloatTensor of size 1]
# , 8.44740915298462)
# (28,
# 1.00000e-03 *
#   2.9211
# [torch.FloatTensor of size 1]
# , 8.41759204864502)
# (29,
# 1.00000e-03 *
#   2.8958
# [torch.FloatTensor of size 1]
# , 8.408833026885986)
# (30,
# 1.00000e-03 *
#   2.8737
# [torch.FloatTensor of size 1]
# , 8.340922832489014)
# (31,
# 1.00000e-03 *
#   2.8555
# [torch.FloatTensor of size 1]
# , 8.473729133605957)
# (32,
# 1.00000e-03 *
#   2.8409
# [torch.FloatTensor of size 1]
# , 8.387485980987549)
# (33,
# 1.00000e-03 *
#   2.8290
# [torch.FloatTensor of size 1]
# , 8.369168996810913)
# (34,
# 1.00000e-03 *
#   2.8194
# [torch.FloatTensor of size 1]
# , 8.34705114364624)
# (35,
# 1.00000e-03 *
#   2.8115
# [torch.FloatTensor of size 1]
# , 8.341356992721558)
# (36,
# 1.00000e-03 *
#   2.8048
# [torch.FloatTensor of size 1]
# , 8.476062059402466)
# (37,
# 1.00000e-03 *
#   2.7992
# [torch.FloatTensor of size 1]
# , 9.034984111785889)
# (38,
# 1.00000e-03 *
#   2.7943
# [torch.FloatTensor of size 1]
# , 9.248876810073853)
# (39,
# 1.00000e-03 *
#   2.7900
# [torch.FloatTensor of size 1]
# , 10.788146018981934)
# (40,
# 1.00000e-03 *
#   2.7863
# [torch.FloatTensor of size 1]
# , 9.88532304763794)
# (41,
# 1.00000e-03 *
#   2.7829
# [torch.FloatTensor of size 1]
# , 10.136465072631836)
# (42,
# 1.00000e-03 *
#   2.7798
# [torch.FloatTensor of size 1]
# , 12.197942972183228)
# (43,
# 1.00000e-03 *
#   2.7770
# [torch.FloatTensor of size 1]
# , 10.630584001541138)
# (44,
# 1.00000e-03 *
#   2.7744
# [torch.FloatTensor of size 1]
# , 10.224065065383911)
# (45,
# 1.00000e-03 *
#   2.7721
# [torch.FloatTensor of size 1]
# , 8.872473001480103)
# (46,
# 1.00000e-03 *
#   2.7699
# [torch.FloatTensor of size 1]
# , 8.770660877227783)
# (47,
# 1.00000e-03 *
#   2.7678
# [torch.FloatTensor of size 1]
# , 10.24144196510315)
# (48,
# 1.00000e-03 *
#   2.7659
# [torch.FloatTensor of size 1]
# , 9.720703840255737)
# (49,
# 1.00000e-03 *
#   2.7641
# [torch.FloatTensor of size 1]
# , 12.229807138442993)
# (50,
# 1.00000e-03 *
#   2.7624
# [torch.FloatTensor of size 1]
# , 10.45346713066101)
# (51,
# 1.00000e-03 *
#   2.7608
# [torch.FloatTensor of size 1]
# , 9.260424137115479)
# (52,
# 1.00000e-03 *
#   2.7593
# [torch.FloatTensor of size 1]
# , 8.842161178588867)
# (53,
# 1.00000e-03 *
#   2.7578
# [torch.FloatTensor of size 1]
# , 8.712415933609009)
# (54,
# 1.00000e-03 *
#   2.7565
# [torch.FloatTensor of size 1]
# , 10.013644933700562)
# (55,
# 1.00000e-03 *
#   2.7551
# [torch.FloatTensor of size 1]
# , 11.753599882125854)
# (56,
# 1.00000e-03 *
#   2.7539
# [torch.FloatTensor of size 1]
# , 9.989962100982666)
# (57,
# 1.00000e-03 *
#   2.7527
# [torch.FloatTensor of size 1]
# , 9.052043914794922)
# (58,
# 1.00000e-03 *
#   2.7515
# [torch.FloatTensor of size 1]
# , 9.348075866699219)
# (59,
# 1.00000e-03 *
#   2.7504
# [torch.FloatTensor of size 1]
# , 9.814356088638306)
# (60,
# 1.00000e-03 *
#   2.7494
# [torch.FloatTensor of size 1]
# , 9.1981520652771)
# (61,
# 1.00000e-03 *
#   2.7484
# [torch.FloatTensor of size 1]
# , 10.916810035705566)
# (62,
# 1.00000e-03 *
#   2.7474
# [torch.FloatTensor of size 1]
# , 10.36971116065979)
# (63,
# 1.00000e-03 *
#   2.7464
# [torch.FloatTensor of size 1]
# , 11.05826210975647)
# (64,
# 1.00000e-03 *
#   2.7455
# [torch.FloatTensor of size 1]
# , 10.720802068710327)
# (65,
# 1.00000e-03 *
#   2.7446
# [torch.FloatTensor of size 1]
# , 10.829801082611084)
# (66,
# 1.00000e-03 *
#   2.7438
# [torch.FloatTensor of size 1]
# , 8.864832878112793)
# (67,
# 1.00000e-03 *
#   2.7429
# [torch.FloatTensor of size 1]
# , 10.252969980239868)
# (68,
# 1.00000e-03 *
#   2.7421
# [torch.FloatTensor of size 1]
# , 9.614791870117188)
# (69,
# 1.00000e-03 *
#   2.7414
# [torch.FloatTensor of size 1]
# , 10.184218168258667)
# (70,
# 1.00000e-03 *
#   2.7406
# [torch.FloatTensor of size 1]
# , 9.662986040115356)
# (71,
# 1.00000e-03 *
#   2.7399
# [torch.FloatTensor of size 1]
# , 9.54876708984375)
# (72,
# 1.00000e-03 *
#   2.7391
# [torch.FloatTensor of size 1]
# , 9.133919954299927)
# (73,
# 1.00000e-03 *
#   2.7384
# [torch.FloatTensor of size 1]
# , 9.881932020187378)
# (74,
# 1.00000e-03 *
#   2.7378
# [torch.FloatTensor of size 1]
# , 9.373163938522339)
# (75,
# 1.00000e-03 *
#   2.7371
# [torch.FloatTensor of size 1]
# , 9.451287984848022)
# (76,
# 1.00000e-03 *
#   2.7365
# [torch.FloatTensor of size 1]
# , 9.643769979476929)
# (77,
# 1.00000e-03 *
#   2.7358
# [torch.FloatTensor of size 1]
# , 9.78090500831604)
# (78,
# 1.00000e-03 *
#   2.7352
# [torch.FloatTensor of size 1]
# , 10.403380155563354)
# (79,
# 1.00000e-03 *
#   2.7346
# [torch.FloatTensor of size 1]
# , 9.824697017669678)
# (80,
# 1.00000e-03 *
#   2.7341
# [torch.FloatTensor of size 1]
# , 10.40433406829834)
# (81,
# 1.00000e-03 *
#   2.7335
# [torch.FloatTensor of size 1]
# , 11.332566022872925)
# (82,
# 1.00000e-03 *
#   2.7329
# [torch.FloatTensor of size 1]
# , 14.139567136764526)
# (83,
# 1.00000e-03 *
#   2.7324
# [torch.FloatTensor of size 1]
# , 12.480463027954102)
# (84,
# 1.00000e-03 *
#   2.7319
# [torch.FloatTensor of size 1]
# , 10.879073143005371)
# (85,
# 1.00000e-03 *
#   2.7313
# [torch.FloatTensor of size 1]
# , 10.570105075836182)
# (86,
# 1.00000e-03 *
#   2.7308
# [torch.FloatTensor of size 1]
# , 11.178518056869507)
# (87,
# 1.00000e-03 *
#   2.7303
# [torch.FloatTensor of size 1]
# , 13.261298894882202)
# (88,
# 1.00000e-03 *
#   2.7298
# [torch.FloatTensor of size 1]
# , 10.175957918167114)
# (89,
# 1.00000e-03 *
#   2.7294
# [torch.FloatTensor of size 1]
# , 10.418827056884766)
# (90,
# 1.00000e-03 *
#   2.7289
# [torch.FloatTensor of size 1]
# , 10.700485229492188)
# (91,
# 1.00000e-03 *
#   2.7284
# [torch.FloatTensor of size 1]
# , 10.620659828186035)
# (92,
# 1.00000e-03 *
#   2.7280
# [torch.FloatTensor of size 1]
# , 10.811729907989502)
# (93,
# 1.00000e-03 *
#   2.7276
# [torch.FloatTensor of size 1]
# , 10.703392028808594)
# (94,
# 1.00000e-03 *
#   2.7271
# [torch.FloatTensor of size 1]
# , 11.154592990875244)
# (95,
# 1.00000e-03 *
#   2.7267
# [torch.FloatTensor of size 1]
# , 10.759365797042847)
# (96,
# 1.00000e-03 *
#   2.7263
# [torch.FloatTensor of size 1]
# , 11.677489995956421)
# (97,
# 1.00000e-03 *
#   2.7259
# [torch.FloatTensor of size 1]
# , 11.397273063659668)
# (98,
# 1.00000e-03 *
#   2.7255
# [torch.FloatTensor of size 1]
# , 11.236809968948364)
# (99,
# 1.00000e-03 *
#   2.7251
# [torch.FloatTensor of size 1]
# , 11.162306070327759)
# torch.Size([784, 3000, 25])
# ('dim norm', torch.Size([784, 3000, 1]))
# (32, 32)
# 0
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7042622)
# 1
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7025374)
# 2
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7035416)
# 3
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7037139)
# 4
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7037079)
# 5
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7039455)
# 6
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7039386)
# 7
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7038717)
# 8
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7037159)
# 9
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7038652)
# 10
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7039456)
# 11
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7040205)
# 12
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7038664)
# 13
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7035484)
# 14
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7026852)
# 15
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7030812)
# 16
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7034725)
# 17
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7037868)
# 18
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7034757)
# 19
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7044071)
# 20
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7045783)
# 21
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7037830)
# 22
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7036173)
# 23
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)
# ('nb 3 of null is ', 7039342)
# 24
# ('nb 1 of null is ', 0)
# torch.Size([47040, 150])
# torch.Size([784, 3000, 1])
# ('nb 2 of null is ', 0)

# %%
test=Nystrom()
input_map=data
test.init_W(input_map,patches_given=False)

# %%
net.Kernel[2].eta

# %%
sb.heatmap(net.Kernel[0].W.data.numpy())
plt.figure()
sb.heatmap(net.Kernel[1].W.data.numpy())
plt.figure()
sb.heatmap(net.Kernel[2].W.data.numpy())

# %%
print(net.Kernel[2].all_patches.size())
sb.heatmap(net.Kernel[2].all_patches[40,:100,:].numpy())

# %%
plt.plot([ u.numpy() for u in net.Kernel[2].training_loss],c='red')
plt.plot([ u.numpy() for u in net.Kernel[0].training_loss])
plt.plot([ u.numpy() for u in net.Kernel[1].training_loss],c='yellow')

# %%
net.Kernel[1].eta

# %%
print(net.Kernel[0].output.size())
sb.heatmap(net.Kernel[0].output[100,:100,:].numpy())
print(X_labels[:10])

# %%
plt.plot([ u.numpy() for u in net.Kernel[1].training_loss])

# %%
sb.heatmap(test.W.data.numpy())

# %%
X_tot=net.Kernel[1].eta
X_tot
#X_tot_2=test.pca.transform(X_tot.view(-1,X_tot.size()[2]).numpy())

# %%
X_tilde=torch.cat((net.Kernel[1].training_data[:,0,:],net.Kernel[1].training_data[:,1,:]), dim=0)
pca=PCA(n_components=np.min([X_tilde.size()[1],15]))
X_tilde2=pca.fit_transform(X_tilde.numpy())
X_tilde2.shape

# %%
input_map=X
    for k in range(self.n_layers):
            print(input_map.size())
            input_map=self.get_activation_map(k)
        return input_map

# %%
X.permute(1,0,2).size()

# %%
kernel_svm = svm.SVC(gamma=.2)
kernel_svm.fit(X.permute(1,0,2).contiguous().view(3000,-1).numpy(), X_labels.numpy())

# %%
#### Une fois que l'archtexture a ete entrainee on peut se servir de la couche finale pour faire de la prediction
kernel_svm_score = kernel_svm.score(X.permute(1,0,2).contiguous().view(3000,-1).numpy(), X_labels.numpy())

# %%
kernel_svm_score

# %%
X_test=train_loader.dataset.train_data[torch.LongTensor(inds[3000:6000])]
X_test_labels=train_loader.dataset.train_labels[torch.LongTensor(inds[3000:6000])]

# %%
X_test.size()

# %%
X_test_out=net.propagate_through_network(X_test)

# %%
tests=kernel_svm.predict(X_test_out.permute(1,0,2).contiguous().view(3000,-1).numpy())

# %%
X_test.shape

# %%
kernel_svm_score = kernel_svm.score(X_test_out.permute(1,0,2).contiguous().view(3000,-1).numpy(), X_test_labels.numpy())

# %%
kernel_svm_score
